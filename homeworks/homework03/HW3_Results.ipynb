# %% [markdown]
# ## Homework №3

# %% [markdown]
# ### Neural Machine Translation in the wild

# %% [markdown]
# Results

# %% [markdown]
# К сожалению, потерял некоторые результаты, так как забыл, что запускал их на коллабе, но, тем не менее, положительные результаты. Для каждой модели код,графики и результат работы находятся в соответствующих ноутбуках и .py файлах.

# %% [markdown]
# ### Baseline + more iters
# * просто добавил количество итераций в базовой модели
#
# BLEU 17.28015043992019

# %% [markdown]
# <img src="plots/more_iters.png">

# %% [markdown]
# ### GRU + attn
# * использовал torchnlp
#
# BLEU 28.37984651913395
#
# my_network_2

# %% [markdown]
# <img src="plots/gru_attn.png">

# %% [markdown]
# ### LSTM + attn
# * попытался не использовать torchnlp
#
# BLEU 31.512063287652413
#
# temp_network

# %% [markdown]
# <img src="plots/lstm_no_torchnlp.png">

# %% [markdown]
# ### LSTM + attn
# * тут уже attn из torchnlp
#
# BLEU 32.21596139834911
#
# my_network

# %% [markdown]
# <img src="plots/lstm_torchnlp.png">

# %% [markdown]
# Хотел бы прокомментировать, что реализовывал то же, что и делал бейзлайн, а не то, что написано в начале задания, руководствуясь тем, что было бы странно давать бейзлайн, который не выполняет целевую задачу.

# %% [markdown]
# P.S.
#
# А еще, хотел поблагодарить, что запушили использование colab. Вынужден был с ним познакомиться и, хотя и забыл, что кернелы там умирают, максимально упростил себе процесс выполнения задания. Раньше, по привычке, удаленно подключался к собственной машине дома с cuda. Теперь жизнь кажется прекраснее.. Осталось разобраться с TPU и торчем, но, я так понимаю, что сейчас это можно реализовать лишь через сторонние либы.
# А еще, наткнулся на Ваш курс по мл в МФТИ. Искренне получил удовольствие. Вообще говоря, хотя бэкграунд мл у меня крайне мал и начало изучения практически совпадает с попаданием на курс MADE, Ваш материал показался одним из наиболее приятных, особенно ноутбуки по всем занятиям. Спасибо.
